# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# Built-in python libraries
import sys
import os
from urllib.request import urlretrieve

# 3rd-party libraries I'll be using
import matplotlib.pyplot as plt
import matplotlib

# %%
print("Python version:\n{}\n".format(sys.version))
print("matplotlib version: {}".format(matplotlib.__version__))
print("pandas version: {}".format(pd.__version__))
print("numpy version: {}".format(np.__version__))
# Out:
# Python version:
# 3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]
#
# matplotlib version: 2.2.2
# pandas version: 0.23.0
# numpy version: 1.14.3

# %%
# %matplotlib inline

# %%
tips_csv = pd.read_csv(r'C:\Users\santosv\Documents\Vitor\Python Machine Learning\seaborn-data-master\tips.csv')

# %%
tips_csv.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips_csv['total_bill'])
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(tips_csv['total_bill'],kde=False,bins=10)
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips_csv,kind='scatter')
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips_csv,kind='hex')
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips_csv,kind='reg')
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(tips_csv)

# %%
sns.pairplot(tips_csv,hue='sex',palette='coolwarm')

# %%
sns.rugplot(tips_csv['total_bill'])

# %%
sns.barplot(x='sex',y='total_bill',data=tips_csv)

# %%
sns.barplot(x='sex',y='total_bill',data=tips_csv,estimator=np.std)

# %%
sns.countplot(x='sex', data=tips_csv)

# %%
sns.boxplot(x='day',y='total_bill',data=tips_csv,palette='rainbow')

# %%
sns.boxplot(x='day',y='total_bill',data=tips_csv,hue='sex')

# %%
sns.boxplot(data=tips_csv, palette='rainbow',orient='h')

# %%
sns.violinplot(x='day',y='tip',data=tips_csv)

# %%
sns.violinplot(x='day',y='tip',data=tips_csv,hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips_csv,jitter=True,hue='sex',split=True)
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips_csv,hue='sex',split=True)
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:2783: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips_csv,color='black')
sns.violinplot(x='day',y='total_bill',data=tips_csv)

# %%
sns.factorplot(x='day',y='total_bill',data=tips_csv,kind='bar')

# %%
flights = pd.read_csv(r'C:\Users\santosv\Documents\Vitor\Python Machine Learning\seaborn-data-master\flights.csv')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
crr=tips_csv.corr()

# %%
sns.heatmap(crr,cmap='coolwarm',annot=True)

# %%
pf = flights.pivot_table(values='passengers',index='month',columns='year')

# %%
pf
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# April       129   135   163   181   235   227   269   313   348   348   396
# August      148   170   199   242   272   293   347   405   467   505   559
# December    118   140   166   194   201   229   278   306   336   337   405
# February    118   126   150   180   196   188   233   277   301   318   342
# January     112   115   145   171   196   204   242   284   315   340   360
# July        148   170   199   230   264   302   364   413   465   491   548
# June        135   149   178   218   243   264   315   374   422   435   472
# March       132   141   178   193   236   235   267   317   356   362   406
# May         121   125   172   183   229   234   270   318   355   363   420
# November    104   114   146   172   180   203   237   271   305   310   362
# October     119   133   162   191   211   229   274   306   347   359   407
# ...

# %%
sns.heatmap(pf, cmap='magma', linecolor='white', linewidths=0.25)

# %%
sns.clustermap(pf, standard_scale=1, cmap='coolwarm')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips_csv,hue='sex',palette='magma',markers=['o','v'],scatter_kws={'s':100})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips_csv,hue='sex',col='sex',row='time')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips_csv,hue='sex',col='day',aspect=0.6,size=8,palette='dark')

# %%
iris = pd.read_csv(r'C:\Users\santosv\Documents\Vitor\Python Machine Learning\seaborn-data-master\iris.csv')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %%
sns.pairplot(iris,hue='species',palette='dark')

# %%
f = sns.FacetGrid(tips_csv, col='time',row='smoker')
f.map(plt.hist,'total_bill')

# %%
f = sns.FacetGrid(tips_csv, col='time',row='smoker')
f.map(plt.scatter,'total_bill','tip')

# %%
sns.set_style('dark')
plt.figure(figsize=(10,4))
sns.countplot(x='sex',data=tips_csv,palette="dark")

# %%
sns.lmplot(x='total_bill',y='tip',data=tips_csv, size=4, aspect=2)

# %%
sns.set_context('paper', font_scale=1.5)
sns.lmplot(x='total_bill',y='tip',data=tips_csv,hue='sex',palette='copper')
