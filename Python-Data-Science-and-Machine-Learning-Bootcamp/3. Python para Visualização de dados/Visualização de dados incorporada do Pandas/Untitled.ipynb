# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Folhas de estilo (bmh, ggplot, )
#plt.style.use('bmh')
sns.set_style('dark')

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

# %%
df2.plot.area(alpha=0.4)

# %%
#Stacked une todos os dados em uma só barra
df2.plot.bar(stacked=True, figsize=(10,4))
plt.legend(loc='upper right')

# %%
df1['A'].plot.hist(grid=True, bins=50)

# %%
df1.plot.line(y='A', figsize=(12,6), lw=1)

# %%
df1.plot.scatter(x='A', y='B', figsize=(12,8), c='C', cmap='inferno', grid=True)

# %%
df1.plot.scatter(x='A', y='B', figsize=(10,5), s=df1['C']*20, grid=True)
# Out:
# C:\Users\santosv\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.box(figsize=(12,8))

# %%
df = pd.DataFrame(np.random.rand(1000,2), columns=['A', 'B'])

# %%
df.head()
# Out:
#           A         B
# 0  0.530838  0.207289
# 1  0.016007  0.741862
# 2  0.114833  0.578718
# 3  0.307197  0.588022
# 4  0.158900  0.503883

# %%
df.plot.hexbin(x='A', y='B', figsize=(12,8), gridsize=20, cmap='Oranges')
